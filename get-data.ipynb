# %%
from datetime import date
import yfinance as yf

# %%
ticker = "BBAJIOO.MX"
start = date(2023, 1, 1)
end = date.today()
data = yf.download(tickers=ticker, start=start, end=end, multi_level_index=False)
data
# Out:
# [*********************100%***********************]  1 of 1 completed
#                 Close       High        Low       Open   Volume
# Date
# 2023-01-02  51.172379  51.602468  50.469349  50.965605    79626
# 2023-01-03  51.536301  52.231061  50.816726  50.866352   834498
# 2023-01-04  52.925823  53.372452  51.544573  52.115267  1703451
# 2023-01-05  51.213730  53.182220  51.122752  52.661146  2454246
# 2023-01-06  53.637123  53.645396  51.569385  51.569385  2345878
# ...               ...        ...        ...        ...      ...
# 2025-04-24  48.349998  48.689999  47.070000  47.889999  1854249
# 2025-04-25  48.930000  48.959999  47.770000  48.349998   969348
# 2025-04-28  49.930000  50.439999  48.669998  48.990002  1035872
# 2025-04-29  48.070000  50.430000  47.459999  50.020000  1450268
# 2025-04-30  47.060001  48.490002  46.189999  48.009998  1252705
#
# [583 rows x 5 columns]

# %%
data = data[["Open", "High", "Low", "Close", "Volume"]]
filename = f"{ticker}.{start.year}-{end.year}.csv"
data.to_csv(filename)

# %%
start.year
# Out:
# 2023
